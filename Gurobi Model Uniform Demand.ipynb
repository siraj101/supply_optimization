# %% [markdown]
# # 1. Environment Setup

# %%
import gurobipy as gp
from gurobipy import GRB
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Data Acquisition

# %% [markdown]
# ### 2.1 Variables Definition

# %%
alloy = ['all_1','all_2','all_3','all_4','all_5']
supplier = ['sup_1','sup_2','sup_3','sup_4','sup_5']
product = ['prod_1','prod_2','prod_3']
month = ['Int', 'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
I = len(alloy)
J = len(supplier)
Z = len(product)
M = len(month)
q = 0.05
mu = 1

# %%
x_name = []
for i in alloy:
    for j in supplier:
        for m in month:
            #value = 'units of '+i+' sourced from '+j+' in '+m
            value = 'order '+i+' | '+j+' | '+m
            x_name.append(value)
            
s_name = []
for m in month:
    for z in product:
        #value = 'units of '+z+' delayed by one month on '+m
        value = 'delay '+z+' | '+m
        s_name.append(value)
        
D_name = []
for m in month:
    for z in product:
        #value = 'units of '+z+' delivered to satisfy demand in '+m
        value = 'deliver '+z+' | '+m
        D_name.append(value)

lambda_1_name = []
for i in alloy:
    for j in supplier:
        for m in month:
            #value = 'if contract upper range exceeded for '+i+' from '+j+' on month '+m
            value = 'exceed '+i+' | '+j+' | '+m
            lambda_1_name.append(value)

lambda_2_name = []
for i in alloy:
    for j in supplier:
        for m in month:
            #value = 'if contract lower range exceeded for '+i+' from '+j+' on month '+m
            value = 'surrender '+i+' | '+j+' | '+m
            lambda_2_name.append(value)

# %% [markdown]
# ### 2.2 Data Filepath

# %%
file_loc = 'Data Templates_v5.xlsx'

# %% [markdown]
# ### 2.3 Contract Upper Threshold

# %%
contract_upper_threshold = pd.read_excel(file_loc,sheet_name='Contract Upper Threshold',header=2, na_values=['NA'], usecols="B:F")
contract_upper_threshold.index=alloy

# %%
h = contract_upper_threshold
contract_upper_threshold
# Out:
#        Supp A  Supp B  Supp C  Supp D  Supp E
# all_1    1500    1000    1500    1000    1200
# all_2   10000    2500    7500    7500    5000
# all_3   10000    3000    6000    4500    1800
# all_4     450     250     450     300     100
# all_5     500     250     450     300     200

# %% [markdown]
# ### 2.4 Contract Lower Threshold

# %%
contract_lower_threshold = pd.read_excel(file_loc,sheet_name='Contract Lower Threshold',header=2, na_values=['NA'], usecols="B:F")
contract_lower_threshold.index=alloy

# %%
l = contract_lower_threshold
contract_lower_threshold
# Out:
#        Supp A  Supp B  Supp C  Supp D  Supp E
# all_1     300     400     450     550     400
# all_2    5000     800    1800    1000     420
# all_3    1500    1200    2500    2000     800
# all_4      42     100      85     100      75
# all_5      84     100     100     120      50

# %% [markdown]
# ### 2.5 Contract Penalties

# %%
contract_penalties = pd.read_excel(file_loc,sheet_name='Contract Penalties',header=2, na_values=['NA'], usecols="B:F")
contract_penalties.index=['Penalty Fee %']

# %%
p = contract_penalties
contract_penalties
# Out:
#                Supp A  Supp B  Supp C  Supp D  Supp E
# Penalty Fee %     0.8     0.6    0.75     0.7     0.5

# %% [markdown]
# ### 2.6 Annual Contract Limit

# %%
annual_contracted_limit= pd.read_excel(file_loc,sheet_name='Annual Contracted Limit',header=2, na_values=['NA'], usecols="B:F")
annual_contracted_limit = annual_contracted_limit.iloc[:5,:]
annual_contracted_limit.index=alloy

# %%
k = annual_contracted_limit
annual_contracted_limit
# Out:
#         Supp A   Supp B   Supp C   Supp D   Supp E
# all_1   9616.2   6956.5   7871.0   7867.8  11807.5
# all_2  67200.0  33600.0  22400.0  44800.0  56000.0
# all_3  17600.0  44000.0  35200.0  35200.0  44000.0
# all_4   1560.0   1872.0   1768.0   3120.0   2080.0
# all_5   1356.0   3616.0   2938.0   1130.0   2260.0

# %% [markdown]
# ### 2.7 Unit Cost

# %%
unit_cost = pd.read_excel(file_loc,sheet_name='Unit Cost',header=2, na_values=['NA'], usecols="B:F")
unit_cost = unit_cost.iloc[:5,:]
unit_cost.index=alloy

# %%
c = unit_cost
unit_cost
# Out:
#            Supp A      Supp B      Supp C      Supp D      Supp E
# all_1  275.000000  274.166667  274.583333  274.416667  273.750000
# all_2   11.250000   10.666667   11.083333   10.833333   10.416667
# all_3    2.333333    1.833333    2.166667    2.000000    1.666667
# all_4  858.333333  855.000000  857.083333  855.833333  853.333333
# all_5  210.833333  204.166667  208.333333  205.833333  202.500000

# %% [markdown]
# ### 2.8 Product Revenue

# %%
prod_rev = pd.read_excel(file_loc,sheet_name='Prod Rev',header=2, na_values=['NA'], usecols="B:F")
prod_rev.index=['Revenue ($)']
# Out:
# D:\anaconda\lib\site-packages\pandas\io\excel\_base.py:1272: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   return self._reader.parse(

# %%
r = prod_rev
prod_rev
# Out:
#              Prod 1  Prod 2  Prod 3
# Revenue ($)   20000   22000   25000

# %% [markdown]
# ### 2.9 Product Recipe

# %%
prod_recipe= pd.read_excel(file_loc,sheet_name='Prod Recipe',header=2, na_values=['NA'], usecols="B:D")
prod_recipe = prod_recipe.iloc[:5,:]
prod_recipe.index=alloy

# %%
u = prod_recipe
prod_recipe
# Out:
#         Prod 1      Prod 2      Prod 3
# all_1   26.226   49.670455    0.000000
# all_2  112.000  152.727273   81.454545
# all_3   88.000   40.000000  256.000000
# all_4    4.160   11.818182    7.563636
# all_5    0.000   15.409091   12.327273

# %% [markdown]
# ### 2.10 Uniform Demand

# %%
uniform_demand= pd.read_excel(file_loc,sheet_name='Uniform Demand',header=2, na_values=['NA'], usecols="B:D")
uniform_demand.index=month

# %%
d = uniform_demand
uniform_demand
# Out:
#         Prod 1     Prod 2     Prod 3
# Int   0.000000   0.000000   0.000000
# Jan  45.833333  18.333333  22.916667
# Feb  45.833333  18.333333  22.916667
# Mar  45.833333  18.333333  22.916667
# Apr  45.833333  18.333333  22.916667
# May  45.833333  18.333333  22.916667
# Jun  45.833333  18.333333  22.916667
# Jul  45.833333  18.333333  22.916667
# Aug  45.833333  18.333333  22.916667
# Sep  45.833333  18.333333  22.916667
# Oct  45.833333  18.333333  22.916667
# Nov  45.833333  18.333333  22.916667
# Dec  45.833333  18.333333  22.916667

# %%
# plot lines

plt.plot(list(range(13)), d['Prod 1'], label = "Demand of Product 1")
plt.plot(list(range(13)), d['Prod 2'], label = "Demand of Product 2")
plt.plot(list(range(13)), d['Prod 3'], label = "Demand of Product 3")
plt.xlabel('Month')
plt.ylabel('Demand')
plt.title('Uniform Demand for Each Month')
plt.legend()
plt.show()

# %% [markdown]
# # 3. Gurobi

# %%
model = gp.Model()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-09-25

# %% [markdown]
# ### 3.1 Decision variables:
#
# $ x_{i,j,m} $ how much of alloy type $ i $ to source from supplier $ j $ in month $ m $
#
# $ s_{m, z} $ how many units of product type $ z $ will be delayed by one month on month $ m $
#
# $ D_{m, z} $ how many units of product type $ z $ were delivered to satisfy demand on month $ m $
#
# $ \lambda^1_{i, j, m} $ a variable indicating how much the order exceeded the upper contract threshold for alloy $i$ from supplier $j$ on month $m$
#
# $ \lambda^2_{i, j, m} $ a variable indicating how much the order fell short of the lower contract threshold for alloy $i$ from supplier $j$ on month $m$

# %%
x = model.addVars(I, J, M, vtype=GRB.CONTINUOUS, lb=0, name=x_name)
s = model.addVars(M,Z, vtype=GRB.CONTINUOUS, lb=0, name=s_name)
D = model.addVars(M,Z, vtype=GRB.CONTINUOUS, lb=0, name=D_name)
lambda1 = model.addVars(I, J, M, vtype=GRB.CONTINUOUS, lb=0, name=lambda_1_name)
lambda2 = model.addVars(I, J, M, vtype=GRB.CONTINUOUS, lb=0, name=lambda_2_name)
total_cost = model.addVar(1,vtype=GRB.CONTINUOUS, name='Total Cost')

# %% [markdown]
# ### 3.2 Objective function
#
# Maximize
#
# $$
# \sum \limits _{m=1} ^{12}\sum \limits _{z=1} ^{3} D_{m, z} r_{z} - \sum \limits _{m=1} ^{12}\sum \limits _{z=1} ^{3} s_{m, z} r_{z}q - \sum \limits _{i=1} ^{5}\sum \limits _{j=1} ^{5}\sum \limits _{m=1} ^{12} c_{i,j}x_{i,j,m} - \sum \limits _{i=1} ^{5}\sum \limits _{j=1} ^{5}\sum \limits _{m=1} ^{12} \lambda^{1}_{i,j,m}p_{j}c_{i,j} - \sum \limits _{i=1} ^{5}\sum \limits _{j=1} ^{5}\sum \limits _{m=1} ^{12} \lambda^{2}_{i,j,m}p_{j}c_{i,j} $$

# %%
revenue = sum(D[m,z]*r.iloc[0,z] for m in range(1, M) for z in range(Z))
delay = sum(s[m,z]*r.iloc[0,z]*q for m in range(1, M) for z in range(Z))
cost = sum(c.iloc[i,j]*x[i,j,m] for i in range(I) for j in range(J) for m in range(1, M))
high = sum(lambda1[i,j,m]*p.iloc[0,j]*c.iloc[i, j] for i in range(I) for j in range(J) for m in range(1, M))
low = sum(lambda2[i,j,m]*p.iloc[0,j]*c.iloc[i, j] for i in range(I) for j in range(J) for m in range(1, M))

# %%
model.setObjective(revenue-delay-cost-high-low,GRB.MAXIMIZE)

# %% [markdown]
# ### 3.3 Constraints:
#
# **Capacity**
#
# $ \sum \limits _{m=1} ^{12} x_{i,j,m} \le k_{i,j} $ $ \forall i = 1,...,5$ and $j = 1,...5 $

# %%
for i in range(I):
    for j in range(J):
        model.addConstr(sum(x[i,j,m] for m in range(1, M))<=k.iloc[i,j], name = "capacity_"+str(i)+str(j))

# %% [markdown]
# **Month 0 Constraints**
#
# $ x_{i,j,m=0} = s_{m=0,z} = D_{m=0} = \lambda^1_{i, j, m=0} = \lambda^2_{i, j, m=0} = 0$ $\forall i = 1, ..., 5$, $j = 1, ..., 5 $, and $ z = 1, .., 3$

# %%
model.addConstrs(x[i,j,0]==0 for i in range(I) for j in range(J))
model.addConstrs(lambda1[i,j,0]==0 for i in range(I) for j in range(J))
model.addConstrs(lambda2[i,j,0]==0 for i in range(I) for j in range(J))
model.addConstrs(s[0,z]==0 for z in range(Z))
model.addConstrs(D[0,z]==0 for z in range(Z))
# Out:
# {0: <gurobi.Constr *Awaiting Model Update*>,
#  1: <gurobi.Constr *Awaiting Model Update*>,
#  2: <gurobi.Constr *Awaiting Model Update*>}

# %% [markdown]
# **Enough Alloys are Sourced to Meet Delivery Requirements (no inventory passed on to next month)**
#
# $\sum \limits _{j=1} ^{5} x_{i,j,m} = \sum \limits _{z=1} ^{3} D_{m,z} u_{i,z}  $ $ \forall m = 1,...,12 $ and $i = 1, ..., 5 $

# %%
for m in range(1, M):
    for i in range(I):
        model.addConstr(sum(x[i,j,m] for j in range(J))==sum(D[m,z]*u.iloc[i,z]/12 for z in range(Z)), name = "need_"+str(m)+str(i))

# %% [markdown]
# **Maximum Delay Capacity**
#
# $s_{m, z} \le \mu (d_{m, z}+s_{m-1, z}) $ $ \forall m = 1,...,12 $ and $ z = 1,...,3 $

# %%
for m in range(1, M):
    for z in range(Z):
        model.addConstr(s[m,z]<=mu*(d.iloc[m,z]+s[m-1,z]), name = "maxDelay_"+str(m)+str(z))

# %% [markdown]
# **Demand Delivered per Month**
#
# $D_{m, z} = s_{m-1, z} + d_{m, z} - s_{m, z} $ $ \forall m = 1, ..., 12$ and $ z = 1, ..., 3 $

# %%
model.addConstrs(s[0,z]==0 for z in range(Z))

for m in range(1,M):
    for z in range(Z):
        model.addConstr(D[m,z] == s[m-1,z] + d.iloc[m,z] - s[m,z], name = "delivery_"+str(m)+str(z))

# %% [markdown]
# **Meet All Demand Predicted Within the Year**
#
# $\sum \limits _{m=1}^{12} D_{m,z} = \sum \limits _{m=1}^{12} d_{m, z} $

# %%
for z in range(Z):
    model.addConstr(sum(D[m,z] for m in range(1, M)) == sum(d.iloc[m,z] for m in range(1, M)), name = "allDemand_"+str(z))

# %% [markdown]
# **Upper limit penalty**
#
# $  x_{i,j,m} - h_{i,j} \le \lambda^1_{i, j, m} $ $\forall i = 1,...,5 $,  $ j = 1,...,5 $, and $ m = 1,...,12 $

# %%
for i in range(I):
    for j in range(J):
        for m in range(M):
            model.addConstr(x[i,j,m]-h.iloc[i,j] <= lambda1[i,j,m],name = "upper_"+str(i)+str(j)+str(m))

# %% [markdown]
# **Lower limit penalty**
#
# $ l_{i,j} - x_{i,j,m} \lambda^2_{i, j, m}  \forall i = 1,...,5 $, $ j = 1,...,5 $, and $ m = 1,...,12 $

# %%
for i in range(I):
    for j in range(J):
        for m in range(1, M):
            model.addConstr(l.iloc[i,j]-x[i,j,m] <= lambda2[i,j,m],name = "lower_"+str(i)+str(j)+str(m))

# %% [markdown]
# **Non-negativity constraints**
#
# $ x_{i,j,m} \ge 0$ $ \forall i = 1,...,5 $, $ j = 1,...,5 $, and $ m = 1,...,12 $
#
# $ s_{m, z} \ge 0$ $\forall m = 1,...,12 $ and $ z = 1,...,3 $
#
# $ D_{m, z} \ge 0$ $\forall m = 1,...,12 $ and $ z = 1,...,3 $
#
# $ \lambda^1_{i, j, m} \ge 0$  $\forall i = 1,...,5$, $ j=1, ..., 5$, and $ m = 1,...,12 $
#
# $ \lambda^2_{i, j, m} \ge 0$  $\forall i = 1,...,5$, $ j=1, ..., 5$, and $ m = 1,...,12 $

# %%
# these constraints are already applied while setting up decision variables

# %% [markdown]
# **Calculating total cost**

# %%
model.addConstr(total_cost==delay+cost+high+low)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# # 4. Result

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 870 rows, 1054 columns and 3243 nonzeros
# Model fingerprint: 0xa5aa1e6f
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+03]
#   Objective range  [8e-01, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 7e+04]
# Presolve removed 115 rows and 85 columns
# Presolve time: 0.02s
# Presolved: 755 rows, 969 columns, 3093 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4709056e+08   1.986178e+05   0.000000e+00      0s
#      396    1.3295528e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 396 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.329552818e+07

# %%
if model.status == GRB.OPTIMAL:
    model.printAttr('X')
# Out:
#     Variable            X
# -------------------------
# order all_1 | sup_1 | Jan      176.054
# order all_1 | sup_1 | Feb      176.054
# order all_1 | sup_1 | Mar      176.054
# order all_1 | sup_1 | Apr      176.054
# order all_1 | sup_1 | May      176.054
# order all_1 | sup_1 | Jun      176.054
# order all_1 | sup_1 | Jul      176.054
# order all_1 | sup_1 | Aug      176.054
# order all_1 | sup_1 | Sep      176.054
# order all_1 | sup_1 | Oct      176.054
# order all_1 | sup_1 | Nov      176.054
# order all_1 | sup_1 | Dec      176.054
# order all_2 | sup_1 | Jan      816.667
# order all_2 | sup_1 | Feb      816.667
# order all_2 | sup_1 | Mar      816.667
# order all_2 | sup_1 | Apr      816.667
# order all_2 | sup_1 | May      816.667
# order all_2 | sup_1 | Jun      816.667
# order all_2 | sup_1 | Jul      816.667
# order all_2 | sup_1 | Aug      816.667
# order all_2 | sup_1 | Sep      816.667
# order all_2 | sup_1 | Oct      816.667
# order all_2 | sup_1 | Nov      816.667
# order all_2 | sup_1 | Dec      816.667
# order all_3 | sup_1 | Jan      886.111
# order all_3 | sup_1 | Feb      886.111
# order all_3 | sup_1 | Mar      886.111
# order all_3 | sup_1 | Apr      886.111
# order all_3 | sup_1 | May      886.111
# order all_3 | sup_1 | Jun      886.111
# order all_3 | sup_1 | Jul      886.111
# order all_3 | sup_1 | Aug      886.111
# order all_3 | sup_1 | Sep      886.111
# order all_3 | sup_1 | Oct      886.111
# order all_3 | sup_1 | Nov      886.111
# order all_3 | sup_1 | Dec      886.111
# order all_4 | sup_1 | Jan           42
# order all_4 | sup_1 | Feb           42
# order all_4 | sup_1 | Mar           42
# order all_4 | sup_1 | Apr           42
# order all_4 | sup_1 | May           42
# order all_4 | sup_1 | Jun           42
# order all_4 | sup_1 | Jul           42
# order all_4 | sup_1 | Aug           42
# order all_4 | sup_1 | Sep           42
# order all_4 | sup_1 | Oct           42
# order all_4 | sup_1 | Nov           42
# order all_4 | sup_1 | Dec           42
# order all_4 | sup_3 | Jan      6.38889
# order all_4 | sup_3 | Feb      6.38889
# order all_4 | sup_3 | Mar      6.38889
# order all_4 | sup_3 | Apr      6.38889
# order all_4 | sup_3 | May      6.38889
# order all_4 | sup_3 | Jun      6.38889
# order all_4 | sup_3 | Jul      6.38889
# order all_4 | sup_3 | Aug      6.38889
# order all_4 | sup_3 | Sep      6.38889
# order all_4 | sup_3 | Oct      6.38889
# order all_4 | sup_3 | Nov      6.38889
# order all_4 | sup_3 | Dec      6.38889
# order all_5 | sup_1 | Jan      47.0833
# order all_5 | sup_1 | Feb      47.0833
# order all_5 | sup_1 | Mar      47.0833
# order all_5 | sup_1 | Apr      47.0833
# order all_5 | sup_1 | May      47.0833
# order all_5 | sup_1 | Jun      47.0833
# order all_5 | sup_1 | Jul      47.0833
# order all_5 | sup_1 | Aug      47.0833
# order all_5 | sup_1 | Sep      47.0833
# order all_5 | sup_1 | Oct      47.0833
# order all_5 | sup_1 | Nov      47.0833
# order all_5 | sup_1 | Dec      47.0833
# deliver prod_1 | Jan      45.8333
# deliver prod_2 | Jan      18.3333
# deliver prod_3 | Jan      22.9167
# deliver prod_1 | Feb      45.8333
# deliver prod_2 | Feb      18.3333
# deliver prod_3 | Feb      22.9167
# deliver prod_1 | Mar      45.8333
# deliver prod_2 | Mar      18.3333
# deliver prod_3 | Mar      22.9167
# deliver prod_1 | Apr      45.8333
# deliver prod_2 | Apr      18.3333
# deliver prod_3 | Apr      22.9167
# deliver prod_1 | May      45.8333
# deliver prod_2 | May      18.3333
# deliver prod_3 | May      22.9167
# deliver prod_1 | Jun      45.8333
# deliver prod_2 | Jun      18.3333
# deliver prod_3 | Jun      22.9167
# deliver prod_1 | Jul      45.8333
# deliver prod_2 | Jul      18.3333
# deliver prod_3 | Jul      22.9167
# deliver prod_1 | Aug      45.8333
# deliver prod_2 | Aug      18.3333
# deliver prod_3 | Aug      22.9167
# deliver prod_1 | Sep      45.8333
# deliver prod_2 | Sep      18.3333
# deliver prod_3 | Sep      22.9167
# deliver prod_1 | Oct      45.8333
# deliver prod_2 | Oct      18.3333
# deliver prod_3 | Oct      22.9167
# deliver prod_1 | Nov      45.8333
# deliver prod_2 | Nov      18.3333
# deliver prod_3 | Nov      22.9167
# deliver prod_1 | Dec      45.8333
# deliver prod_2 | Dec      18.3333
# deliver prod_3 | Dec      22.9167
# surrender all_1 | sup_1 | Jan      123.946
# surrender all_1 | sup_1 | Feb      123.946
# surrender all_1 | sup_1 | Mar      123.946
# surrender all_1 | sup_1 | Apr      123.946
# surrender all_1 | sup_1 | May      123.946
# surrender all_1 | sup_1 | Jun      123.946
# surrender all_1 | sup_1 | Jul      123.946
# surrender all_1 | sup_1 | Aug      123.946
# surrender all_1 | sup_1 | Sep      123.946
# surrender all_1 | sup_1 | Oct      123.946
# surrender all_1 | sup_1 | Nov      123.946
# surrender all_1 | sup_1 | Dec      123.946
# surrender all_1 | sup_2 | Jan          400
# surrender all_1 | sup_2 | Feb          400
# surrender all_1 | sup_2 | Mar          400
# surrender all_1 | sup_2 | Apr          400
# surrender all_1 | sup_2 | May          400
# surrender all_1 | sup_2 | Jun          400
# surrender all_1 | sup_2 | Jul          400
# surrender all_1 | sup_2 | Aug          400
# surrender all_1 | sup_2 | Sep          400
# surrender all_1 | sup_2 | Oct          400
# surrender all_1 | sup_2 | Nov          400
# surrender all_1 | sup_2 | Dec          400
# surrender all_1 | sup_3 | Jan          450
# surrender all_1 | sup_3 | Feb          450
# surrender all_1 | sup_3 | Mar          450
# surrender all_1 | sup_3 | Apr          450
# surrender all_1 | sup_3 | May          450
# surrender all_1 | sup_3 | Jun          450
# surrender all_1 | sup_3 | Jul          450
# surrender all_1 | sup_3 | Aug          450
# surrender all_1 | sup_3 | Sep          450
# surrender all_1 | sup_3 | Oct          450
# surrender all_1 | sup_3 | Nov          450
# surrender all_1 | sup_3 | Dec          450
# surrender all_1 | sup_4 | Jan          550
# surrender all_1 | sup_4 | Feb          550
# surrender all_1 | sup_4 | Mar          550
# surrender all_1 | sup_4 | Apr          550
# surrender all_1 | sup_4 | May          550
# surrender all_1 | sup_4 | Jun          550
# surrender all_1 | sup_4 | Jul          550
# surrender all_1 | sup_4 | Aug          550
# surrender all_1 | sup_4 | Sep          550
# surrender all_1 | sup_4 | Oct          550
# surrender all_1 | sup_4 | Nov          550
# surrender all_1 | sup_4 | Dec          550
# surrender all_1 | sup_5 | Jan          400
# surrender all_1 | sup_5 | Feb          400
# surrender all_1 | sup_5 | Mar          400
# surrender all_1 | sup_5 | Apr          400
# surrender all_1 | sup_5 | May          400
# surrender all_1 | sup_5 | Jun          400
# surrender all_1 | sup_5 | Jul          400
# surrender all_1 | sup_5 | Aug          400
# surrender all_1 | sup_5 | Sep          400
# surrender all_1 | sup_5 | Oct          400
# surrender all_1 | sup_5 | Nov          400
# surrender all_1 | sup_5 | Dec          400
# surrender all_2 | sup_1 | Jan      4183.33
# surrender all_2 | sup_1 | Feb      4183.33
# surrender all_2 | sup_1 | Mar      4183.33
# surrender all_2 | sup_1 | Apr      4183.33
# surrender all_2 | sup_1 | May      4183.33
# surrender all_2 | sup_1 | Jun      4183.33
# surrender all_2 | sup_1 | Jul      4183.33
# surrender all_2 | sup_1 | Aug      4183.33
# surrender all_2 | sup_1 | Sep      4183.33
# surrender all_2 | sup_1 | Oct      4183.33
# surrender all_2 | sup_1 | Nov      4183.33
# surrender all_2 | sup_1 | Dec      4183.33
# surrender all_2 | sup_2 | Jan          800
# surrender all_2 | sup_2 | Feb          800
# surrender all_2 | sup_2 | Mar          800
# surrender all_2 | sup_2 | Apr          800
# surrender all_2 | sup_2 | May          800
# surrender all_2 | sup_2 | Jun          800
# surrender all_2 | sup_2 | Jul          800
# surrender all_2 | sup_2 | Aug          800
# surrender all_2 | sup_2 | Sep          800
# surrender all_2 | sup_2 | Oct          800
# surrender all_2 | sup_2 | Nov          800
# surrender all_2 | sup_2 | Dec          800
# surrender all_2 | sup_3 | Jan         1800
# surrender all_2 | sup_3 | Feb         1800
# surrender all_2 | sup_3 | Mar         1800
# surrender all_2 | sup_3 | Apr         1800
# surrender all_2 | sup_3 | May         1800
# surrender all_2 | sup_3 | Jun         1800
# surrender all_2 | sup_3 | Jul         1800
# surrender all_2 | sup_3 | Aug         1800
# surrender all_2 | sup_3 | Sep         1800
# surrender all_2 | sup_3 | Oct         1800
# surrender all_2 | sup_3 | Nov         1800
# surrender all_2 | sup_3 | Dec         1800
# surrender all_2 | sup_4 | Jan         1000
# surrender all_2 | sup_4 | Feb         1000
# surrender all_2 | sup_4 | Mar         1000
# surrender all_2 | sup_4 | Apr         1000
# surrender all_2 | sup_4 | May         1000
# surrender all_2 | sup_4 | Jun         1000
# surrender all_2 | sup_4 | Jul         1000
# surrender all_2 | sup_4 | Aug         1000
# surrender all_2 | sup_4 | Sep         1000
# surrender all_2 | sup_4 | Oct         1000
# surrender all_2 | sup_4 | Nov         1000
# surrender all_2 | sup_4 | Dec         1000
# surrender all_2 | sup_5 | Jan          420
# surrender all_2 | sup_5 | Feb          420
# surrender all_2 | sup_5 | Mar          420
# surrender all_2 | sup_5 | Apr          420
# surrender all_2 | sup_5 | May          420
# surrender all_2 | sup_5 | Jun          420
# surrender all_2 | sup_5 | Jul          420
# surrender all_2 | sup_5 | Aug          420
# surrender all_2 | sup_5 | Sep          420
# surrender all_2 | sup_5 | Oct          420
# surrender all_2 | sup_5 | Nov          420
# surrender all_2 | sup_5 | Dec          420
# surrender all_3 | sup_1 | Jan      613.889
# surrender all_3 | sup_1 | Feb      613.889
# surrender all_3 | sup_1 | Mar      613.889
# surrender all_3 | sup_1 | Apr      613.889
# surrender all_3 | sup_1 | May      613.889
# surrender all_3 | sup_1 | Jun      613.889
# surrender all_3 | sup_1 | Jul      613.889
# surrender all_3 | sup_1 | Aug      613.889
# surrender all_3 | sup_1 | Sep      613.889
# surrender all_3 | sup_1 | Oct      613.889
# surrender all_3 | sup_1 | Nov      613.889
# surrender all_3 | sup_1 | Dec      613.889
# surrender all_3 | sup_2 | Jan         1200
# surrender all_3 | sup_2 | Feb         1200
# surrender all_3 | sup_2 | Mar         1200
# surrender all_3 | sup_2 | Apr         1200
# surrender all_3 | sup_2 | May         1200
# surrender all_3 | sup_2 | Jun         1200
# surrender all_3 | sup_2 | Jul         1200
# surrender all_3 | sup_2 | Aug         1200
# surrender all_3 | sup_2 | Sep         1200
# surrender all_3 | sup_2 | Oct         1200
# surrender all_3 | sup_2 | Nov         1200
# surrender all_3 | sup_2 | Dec         1200
# surrender all_3 | sup_3 | Jan         2500
# surrender all_3 | sup_3 | Feb         2500
# surrender all_3 | sup_3 | Mar         2500
# surrender all_3 | sup_3 | Apr         2500
# surrender all_3 | sup_3 | May         2500
# surrender all_3 | sup_3 | Jun         2500
# surrender all_3 | sup_3 | Jul         2500
# surrender all_3 | sup_3 | Aug         2500
# surrender all_3 | sup_3 | Sep         2500
# surrender all_3 | sup_3 | Oct         2500
# surrender all_3 | sup_3 | Nov         2500
# surrender all_3 | sup_3 | Dec         2500
# surrender all_3 | sup_4 | Jan         2000
# surrender all_3 | sup_4 | Feb         2000
# surrender all_3 | sup_4 | Mar         2000
# surrender all_3 | sup_4 | Apr         2000
# surrender all_3 | sup_4 | May         2000
# surrender all_3 | sup_4 | Jun         2000
# surrender all_3 | sup_4 | Jul         2000
# surrender all_3 | sup_4 | Aug         2000
# surrender all_3 | sup_4 | Sep         2000
# surrender all_3 | sup_4 | Oct         2000
# surrender all_3 | sup_4 | Nov         2000
# surrender all_3 | sup_4 | Dec         2000
# surrender all_3 | sup_5 | Jan          800
# surrender all_3 | sup_5 | Feb          800
# surrender all_3 | sup_5 | Mar          800
# surrender all_3 | sup_5 | Apr          800
# surrender all_3 | sup_5 | May          800
# surrender all_3 | sup_5 | Jun          800
# surrender all_3 | sup_5 | Jul          800
# surrender all_3 | sup_5 | Aug          800
# surrender all_3 | sup_5 | Sep          800
# surrender all_3 | sup_5 | Oct          800
# surrender all_3 | sup_5 | Nov          800
# surrender all_3 | sup_5 | Dec          800
# surrender all_4 | sup_2 | Jan          100
# surrender all_4 | sup_2 | Feb          100
# surrender all_4 | sup_2 | Mar          100
# surrender all_4 | sup_2 | Apr          100
# surrender all_4 | sup_2 | May          100
# surrender all_4 | sup_2 | Jun          100
# surrender all_4 | sup_2 | Jul          100
# surrender all_4 | sup_2 | Aug          100
# surrender all_4 | sup_2 | Sep          100
# surrender all_4 | sup_2 | Oct          100
# surrender all_4 | sup_2 | Nov          100
# surrender all_4 | sup_2 | Dec          100
# surrender all_4 | sup_3 | Jan      78.6111
# surrender all_4 | sup_3 | Feb      78.6111
# surrender all_4 | sup_3 | Mar      78.6111
# surrender all_4 | sup_3 | Apr      78.6111
# surrender all_4 | sup_3 | May      78.6111
# surrender all_4 | sup_3 | Jun      78.6111
# surrender all_4 | sup_3 | Jul      78.6111
# surrender all_4 | sup_3 | Aug      78.6111
# surrender all_4 | sup_3 | Sep      78.6111
# surrender all_4 | sup_3 | Oct      78.6111
# surrender all_4 | sup_3 | Nov      78.6111
# surrender all_4 | sup_3 | Dec      78.6111
# surrender all_4 | sup_4 | Jan          100
# surrender all_4 | sup_4 | Feb          100
# surrender all_4 | sup_4 | Mar          100
# surrender all_4 | sup_4 | Apr          100
# surrender all_4 | sup_4 | May          100
# surrender all_4 | sup_4 | Jun          100
# surrender all_4 | sup_4 | Jul          100
# surrender all_4 | sup_4 | Aug          100
# surrender all_4 | sup_4 | Sep          100
# surrender all_4 | sup_4 | Oct          100
# surrender all_4 | sup_4 | Nov          100
# surrender all_4 | sup_4 | Dec          100
# surrender all_4 | sup_5 | Jan           75
# surrender all_4 | sup_5 | Feb           75
# surrender all_4 | sup_5 | Mar           75
# surrender all_4 | sup_5 | Apr           75
# surrender all_4 | sup_5 | May           75
# surrender all_4 | sup_5 | Jun           75
# surrender all_4 | sup_5 | Jul           75
# surrender all_4 | sup_5 | Aug           75
# surrender all_4 | sup_5 | Sep           75
# surrender all_4 | sup_5 | Oct           75
# surrender all_4 | sup_5 | Nov           75
# surrender all_4 | sup_5 | Dec           75
# surrender all_5 | sup_1 | Jan      36.9167
# surrender all_5 | sup_1 | Feb      36.9167
# surrender all_5 | sup_1 | Mar      36.9167
# surrender all_5 | sup_1 | Apr      36.9167
# surrender all_5 | sup_1 | May      36.9167
# surrender all_5 | sup_1 | Jun      36.9167
# surrender all_5 | sup_1 | Jul      36.9167
# surrender all_5 | sup_1 | Aug      36.9167
# surrender all_5 | sup_1 | Sep      36.9167
# surrender all_5 | sup_1 | Oct      36.9167
# surrender all_5 | sup_1 | Nov      36.9167
# surrender all_5 | sup_1 | Dec      36.9167
# surrender all_5 | sup_2 | Jan          100
# surrender all_5 | sup_2 | Feb          100
# surrender all_5 | sup_2 | Mar          100
# surrender all_5 | sup_2 | Apr          100
# surrender all_5 | sup_2 | May          100
# surrender all_5 | sup_2 | Jun          100
# surrender all_5 | sup_2 | Jul          100
# surrender all_5 | sup_2 | Aug          100
# surrender all_5 | sup_2 | Sep          100
# surrender all_5 | sup_2 | Oct          100
# surrender all_5 | sup_2 | Nov          100
# surrender all_5 | sup_2 | Dec          100
# surrender all_5 | sup_3 | Jan          100
# surrender all_5 | sup_3 | Feb          100
# surrender all_5 | sup_3 | Mar          100
# surrender all_5 | sup_3 | Apr          100
# surrender all_5 | sup_3 | May          100
# surrender all_5 | sup_3 | Jun          100
# surrender all_5 | sup_3 | Jul          100
# surrender all_5 | sup_3 | Aug          100
# surrender all_5 | sup_3 | Sep          100
# surrender all_5 | sup_3 | Oct          100
# surrender all_5 | sup_3 | Nov          100
# surrender all_5 | sup_3 | Dec          100
# surrender all_5 | sup_4 | Jan          120
# surrender all_5 | sup_4 | Feb          120
# surrender all_5 | sup_4 | Mar          120
# surrender all_5 | sup_4 | Apr          120
# surrender all_5 | sup_4 | May          120
# surrender all_5 | sup_4 | Jun          120
# surrender all_5 | sup_4 | Jul          120
# surrender all_5 | sup_4 | Aug          120
# surrender all_5 | sup_4 | Sep          120
# surrender all_5 | sup_4 | Oct          120
# surrender all_5 | sup_4 | Nov          120
# surrender all_5 | sup_4 | Dec          120
# surrender all_5 | sup_5 | Jan           50
# surrender all_5 | sup_5 | Feb           50
# surrender all_5 | sup_5 | Mar           50
# surrender all_5 | sup_5 | Apr           50
# surrender all_5 | sup_5 | May           50
# surrender all_5 | sup_5 | Jun           50
# surrender all_5 | sup_5 | Jul           50
# surrender all_5 | sup_5 | Aug           50
# surrender all_5 | sup_5 | Sep           50
# surrender all_5 | sup_5 | Oct           50
# surrender all_5 | sup_5 | Nov           50
# surrender all_5 | sup_5 | Dec           50
#   Total Cost  9.41947e+06

# %%
def sen_report(model):
    print('Sensitivity Analysis (SA)\n ObjVal =', model.ObjVal)
    model.printAttr(['X', 'Obj', 'SAObjLow', 'SAObjUp'])
    model.printAttr(['X', 'RC', 'LB', 'SALBLow', 'SALBUp', 'UB', 'SAUBLow', 'SAUBUp'])
    model.printAttr(['Sense', 'Slack', 'Pi', 'RHS', 'SARHSLow', 'SARHSUp']) # Pi = shadow price
    # NOTE: printAttr prints only rows with at least one NON-ZERO value, e.g. model.printAttr('X') prints only non-zero variable values

# %%
sen_report(model)
# Out:
# Sensitivity Analysis (SA)
#  ObjVal = 13295528.180555537
#
#     Variable            X          Obj     SAObjLow      SAObjUp
# ----------------------------------------------------------------
# order all_1 | sup_1 | Int            0            0         -inf           -0
# order all_1 | sup_1 | Jan      176.054         -275     -288.646         -275
# order all_1 | sup_1 | Feb      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Mar      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Apr      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | May      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Jun      176.054         -275         -275     -9.24846
# order all_1 | sup_1 | Jul      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Aug      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Sep      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Oct      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Nov      176.054         -275     -288.646     -9.24846
# order all_1 | sup_1 | Dec      176.054         -275     -288.646     -9.24846
# order all_1 | sup_2 | Int            0            0         -inf           -0
# order all_1 | sup_2 | Jan            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Feb            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Mar            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Apr            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | May            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Jun            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Jul            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Aug            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Sep            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Oct            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Nov            0     -274.167         -inf       -219.5
# order all_1 | sup_2 | Dec            0     -274.167         -inf       -219.5
# order all_1 | sup_3 | Int            0            0         -inf           -0
# order all_1 | sup_3 | Jan            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Feb            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Mar            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Apr            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | May            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Jun            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Jul            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Aug            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Sep            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Oct            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Nov            0     -274.583         -inf     -260.938
# order all_1 | sup_3 | Dec            0     -274.583         -inf     -260.938
# order all_1 | sup_4 | Int            0            0         -inf           -0
# order all_1 | sup_4 | Jan            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Feb            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Mar            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Apr            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | May            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Jun            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Jul            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Aug            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Sep            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Oct            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Nov            0     -274.417         -inf     -247.092
# order all_1 | sup_4 | Dec            0     -274.417         -inf     -247.092
# order all_1 | sup_5 | Int            0            0         -inf           -0
# order all_1 | sup_5 | Jan            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Feb            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Mar            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Apr            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | May            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Jun            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Jul            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Aug            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Sep            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Oct            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Nov            0      -273.75         -inf     -191.875
# order all_1 | sup_5 | Dec            0      -273.75         -inf     -191.875
# order all_2 | sup_1 | Int            0            0         -inf           -0
# order all_2 | sup_1 | Jan      816.667       -11.25     -11.7708       -11.25
# order all_2 | sup_1 | Feb      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Mar      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Apr      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | May      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Jun      816.667       -11.25       -11.25      75.1786
# order all_2 | sup_1 | Jul      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Aug      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Sep      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Oct      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Nov      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_1 | Dec      816.667       -11.25     -11.7708      75.1786
# order all_2 | sup_2 | Int            0            0         -inf           -0
# order all_2 | sup_2 | Jan            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Feb            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Mar            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Apr            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | May            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Jun            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Jul            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Aug            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Sep            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Oct            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Nov            0     -10.6667         -inf        -8.65
# order all_2 | sup_2 | Dec            0     -10.6667         -inf        -8.65
# order all_2 | sup_3 | Int            0            0         -inf           -0
# order all_2 | sup_3 | Jan            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Feb            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Mar            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Apr            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | May            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Jun            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Jul            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Aug            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Sep            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Oct            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Nov            0     -11.0833         -inf     -10.5625
# order all_2 | sup_3 | Dec            0     -11.0833         -inf     -10.5625
# order all_2 | sup_4 | Int            0            0         -inf           -0
# order all_2 | sup_4 | Jan            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Feb            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Mar            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Apr            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | May            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Jun            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Jul            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Aug            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Sep            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Oct            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Nov            0     -10.8333         -inf     -9.83333
# order all_2 | sup_4 | Dec            0     -10.8333         -inf     -9.83333
# order all_2 | sup_5 | Int            0            0         -inf           -0
# order all_2 | sup_5 | Jan            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Feb            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Mar            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Apr            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | May            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Jun            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Jul            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Aug            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Sep            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Oct            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Nov            0     -10.4167         -inf     -7.45833
# order all_2 | sup_5 | Dec            0     -10.4167         -inf     -7.45833
# order all_3 | sup_1 | Int            0            0         -inf           -0
# order all_3 | sup_1 | Jan      886.111     -2.33333     -2.40833     -2.33333
# order all_3 | sup_1 | Feb      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Mar      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Apr      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | May      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Jun      886.111     -2.33333     -2.33333      56.2604
# order all_3 | sup_1 | Jul      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Aug      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Sep      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Oct      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Nov      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_1 | Dec      886.111     -2.33333     -2.40833      56.2604
# order all_3 | sup_2 | Int            0            0         -inf           -0
# order all_3 | sup_2 | Jan            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Feb            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Mar            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Apr            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | May            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Jun            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Jul            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Aug            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Sep            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Oct            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Nov            0     -1.83333         -inf     -1.56667
# order all_3 | sup_2 | Dec            0     -1.83333         -inf     -1.56667
# order all_3 | sup_3 | Int            0            0         -inf           -0
# order all_3 | sup_3 | Jan            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Feb            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Mar            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Apr            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | May            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Jun            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Jul            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Aug            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Sep            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Oct            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Nov            0     -2.16667         -inf     -2.09167
# order all_3 | sup_3 | Dec            0     -2.16667         -inf     -2.09167
# order all_3 | sup_4 | Int            0            0         -inf           -0
# order all_3 | sup_4 | Jan            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Feb            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Mar            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Apr            0           -2         -inf     -1.86667
# order all_3 | sup_4 | May            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Jun            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Jul            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Aug            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Sep            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Oct            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Nov            0           -2         -inf     -1.86667
# order all_3 | sup_4 | Dec            0           -2         -inf     -1.86667
# order all_3 | sup_5 | Int            0            0         -inf           -0
# order all_3 | sup_5 | Jan            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Feb            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Mar            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Apr            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | May            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Jun            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Jul            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Aug            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Sep            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Oct            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Nov            0     -1.66667         -inf         -1.3
# order all_3 | sup_5 | Dec            0     -1.66667         -inf         -1.3
# order all_4 | sup_1 | Int            0            0         -inf           -0
# order all_4 | sup_1 | Jan           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Feb           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Mar           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Apr           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | May           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Jun           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Jul           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Aug           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Sep           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Oct           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Nov           42     -858.333     -900.938     -214.271
# order all_4 | sup_1 | Dec           42     -858.333     -900.938     -214.271
# order all_4 | sup_2 | Int            0            0         -inf           -0
# order all_4 | sup_2 | Jan            0         -855         -inf     -727.271
# order all_4 | sup_2 | Feb            0         -855         -inf     -727.271
# order all_4 | sup_2 | Mar            0         -855         -inf     -727.271
# order all_4 | sup_2 | Apr            0         -855         -inf     -727.271
# order all_4 | sup_2 | May            0         -855         -inf     -727.271
# order all_4 | sup_2 | Jun            0         -855         -inf     -727.271
# order all_4 | sup_2 | Jul            0         -855         -inf     -727.271
# order all_4 | sup_2 | Aug            0         -855         -inf     -727.271
# order all_4 | sup_2 | Sep            0         -855         -inf     -727.271
# order all_4 | sup_2 | Oct            0         -855         -inf     -727.271
# order all_4 | sup_2 | Nov            0         -855         -inf     -727.271
# order all_4 | sup_2 | Dec            0         -855         -inf     -727.271
# order all_4 | sup_3 | Int            0            0         -inf           -0
# order all_4 | sup_3 | Jan      6.38889     -857.083     -899.562     -857.083
# order all_4 | sup_3 | Feb      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Mar      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Apr      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | May      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Jun      6.38889     -857.083     -857.083     -814.479
# order all_4 | sup_3 | Jul      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Aug      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Sep      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Oct      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Nov      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_3 | Dec      6.38889     -857.083     -899.562     -814.479
# order all_4 | sup_4 | Int            0            0         -inf           -0
# order all_4 | sup_4 | Jan            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Feb            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Mar            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Apr            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | May            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Jun            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Jul            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Aug            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Sep            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Oct            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Nov            0     -855.833         -inf     -813.354
# order all_4 | sup_4 | Dec            0     -855.833         -inf     -813.354
# order all_4 | sup_5 | Int            0            0         -inf           -0
# order all_4 | sup_5 | Jan            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Feb            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Mar            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Apr            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | May            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Jun            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Jul            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Aug            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Sep            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Oct            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Nov            0     -853.333         -inf     -640.938
# order all_4 | sup_5 | Dec            0     -853.333         -inf     -640.938
# order all_5 | sup_1 | Int            0            0         -inf           -0
# order all_5 | sup_1 | Jan      47.0833     -210.833      -220.75     -210.833
# order all_5 | sup_1 | Feb      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Mar      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Apr      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | May      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Jun      47.0833     -210.833     -210.833      645.804
# order all_5 | sup_1 | Jul      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Aug      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Sep      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Oct      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Nov      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_1 | Dec      47.0833     -210.833      -220.75      645.804
# order all_5 | sup_2 | Int            0            0         -inf           -0
# order all_5 | sup_2 | Jan            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Feb            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Mar            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Apr            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | May            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Jun            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Jul            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Aug            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Sep            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Oct            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Nov            0     -204.167         -inf     -164.667
# order all_5 | sup_2 | Dec            0     -204.167         -inf     -164.667
# order all_5 | sup_3 | Int            0            0         -inf           -0
# order all_5 | sup_3 | Jan            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Feb            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Mar            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Apr            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | May            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Jun            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Jul            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Aug            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Sep            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Oct            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Nov            0     -208.333         -inf     -198.417
# order all_5 | sup_3 | Dec            0     -208.333         -inf     -198.417
# order all_5 | sup_4 | Int            0            0         -inf           -0
# order all_5 | sup_4 | Jan            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Feb            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Mar            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Apr            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | May            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Jun            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Jul            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Aug            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Sep            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Oct            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Nov            0     -205.833         -inf      -186.25
# order all_5 | sup_4 | Dec            0     -205.833         -inf      -186.25
# order all_5 | sup_5 | Int            0            0         -inf           -0
# order all_5 | sup_5 | Jan            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Feb            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Mar            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Apr            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | May            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Jun            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Jul            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Aug            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Sep            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Oct            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Nov            0       -202.5         -inf     -143.417
# order all_5 | sup_5 | Dec            0       -202.5         -inf     -143.417
# delay prod_1 | Int            0            0         -inf          inf
# delay prod_2 | Int            0            0         -inf           -0
# delay prod_3 | Int            0            0         -inf           -0
# delay prod_1 | Jan            0        -1000         -inf -1.93268e-12
# delay prod_2 | Jan            0        -1100         -inf  2.50111e-12
# delay prod_3 | Jan            0        -1250         -inf  4.54747e-13
# delay prod_1 | Feb            0        -1000         -inf           -0
# delay prod_2 | Feb            0        -1100         -inf           -0
# delay prod_3 | Feb            0        -1250         -inf           -0
# delay prod_1 | Mar            0        -1000         -inf           -0
# delay prod_2 | Mar            0        -1100         -inf           -0
# delay prod_3 | Mar            0        -1250         -inf           -0
# delay prod_1 | Apr            0        -1000         -inf           -0
# delay prod_2 | Apr            0        -1100         -inf           -0
# delay prod_3 | Apr            0        -1250         -inf           -0
# delay prod_1 | May            0        -1000         -inf  1.93268e-12
# delay prod_2 | May            0        -1100         -inf -2.50111e-12
# delay prod_3 | May            0        -1250         -inf -4.54747e-13
# delay prod_1 | Jun            0        -1000         -inf -1.93268e-12
# delay prod_2 | Jun            0        -1100         -inf  2.50111e-12
# delay prod_3 | Jun            0        -1250         -inf  4.54747e-13
# delay prod_1 | Jul            0        -1000         -inf           -0
# delay prod_2 | Jul            0        -1100         -inf           -0
# delay prod_3 | Jul            0        -1250         -inf           -0
# delay prod_1 | Aug            0        -1000         -inf           -0
# delay prod_2 | Aug            0        -1100         -inf           -0
# delay prod_3 | Aug            0        -1250         -inf           -0
# delay prod_1 | Sep            0        -1000         -inf           -0
# delay prod_2 | Sep            0        -1100         -inf           -0
# delay prod_3 | Sep            0        -1250         -inf           -0
# delay prod_1 | Oct            0        -1000         -inf           -0
# delay prod_2 | Oct            0        -1100         -inf           -0
# delay prod_3 | Oct            0        -1250         -inf           -0
# delay prod_1 | Nov            0        -1000         -inf           -0
# delay prod_2 | Nov            0        -1100         -inf           -0
# delay prod_3 | Nov            0        -1250         -inf           -0
# delay prod_1 | Dec            0        -1000         -inf  1.93268e-12
# delay prod_2 | Dec            0        -1100         -inf -2.50111e-12
# delay prod_3 | Dec            0        -1250         -inf -4.54747e-13
# deliver prod_1 | Int            0            0         -inf          inf
# deliver prod_2 | Int            0            0         -inf          inf
# deliver prod_3 | Int            0            0         -inf          inf
# deliver prod_1 | Jan      45.8333        20000        19000          inf
# deliver prod_2 | Jan      18.3333        22000        20900        22000
# deliver prod_3 | Jan      22.9167        25000        23750        25000
# deliver prod_1 | Feb      45.8333        20000        19000        21000
# deliver prod_2 | Feb      18.3333        22000        20900        23100
# deliver prod_3 | Feb      22.9167        25000        23750        26250
# deliver prod_1 | Mar      45.8333        20000        19000        21000
# deliver prod_2 | Mar      18.3333        22000        20900        23100
# deliver prod_3 | Mar      22.9167        25000        23750        26250
# deliver prod_1 | Apr      45.8333        20000        19000        21000
# deliver prod_2 | Apr      18.3333        22000        20900        23100
# deliver prod_3 | Apr      22.9167        25000        23750        26250
# deliver prod_1 | May      45.8333        20000        19000        21000
# deliver prod_2 | May      18.3333        22000        20900        23100
# deliver prod_3 | May      22.9167        25000        23750        26250
# deliver prod_1 | Jun      45.8333        20000        19000        21000
# deliver prod_2 | Jun      18.3333        22000        22000        23100
# deliver prod_3 | Jun      22.9167        25000        25000        26250
# deliver prod_1 | Jul      45.8333        20000        19000        21000
# deliver prod_2 | Jul      18.3333        22000        20900        23100
# deliver prod_3 | Jul      22.9167        25000        23750        26250
# deliver prod_1 | Aug      45.8333        20000        19000        21000
# deliver prod_2 | Aug      18.3333        22000        20900        23100
# deliver prod_3 | Aug      22.9167        25000        23750        26250
# deliver prod_1 | Sep      45.8333        20000        19000        21000
# deliver prod_2 | Sep      18.3333        22000        20900        23100
# deliver prod_3 | Sep      22.9167        25000        23750        26250
# deliver prod_1 | Oct      45.8333        20000        19000        21000
# deliver prod_2 | Oct      18.3333        22000        20900        23100
# deliver prod_3 | Oct      22.9167        25000        23750        26250
# deliver prod_1 | Nov      45.8333        20000        19000        21000
# deliver prod_2 | Nov      18.3333        22000        20900        23100
# deliver prod_3 | Nov      22.9167        25000        23750        26250
# deliver prod_1 | Dec      45.8333        20000        19000        21000
# deliver prod_2 | Dec      18.3333        22000        20900        23100
# deliver prod_3 | Dec      22.9167        25000        23750        26250
# exceed all_1 | sup_1 | Int            0            0         -inf           -0
# exceed all_1 | sup_1 | Jan            0         -220         -inf           -0
# exceed all_1 | sup_1 | Feb            0         -220         -inf           -0
# exceed all_1 | sup_1 | Mar            0         -220         -inf           -0
# exceed all_1 | sup_1 | Apr            0         -220         -inf           -0
# exceed all_1 | sup_1 | May            0         -220         -inf           -0
# exceed all_1 | sup_1 | Jun            0         -220         -inf           -0
# exceed all_1 | sup_1 | Jul            0         -220         -inf           -0
# exceed all_1 | sup_1 | Aug            0         -220         -inf           -0
# exceed all_1 | sup_1 | Sep            0         -220         -inf           -0
# exceed all_1 | sup_1 | Oct            0         -220         -inf           -0
# exceed all_1 | sup_1 | Nov            0         -220         -inf           -0
# exceed all_1 | sup_1 | Dec            0         -220         -inf           -0
# exceed all_1 | sup_2 | Int            0            0         -inf           -0
# exceed all_1 | sup_2 | Jan            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Feb            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Mar            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Apr            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | May            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Jun            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Jul            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Aug            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Sep            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Oct            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Nov            0       -164.5         -inf           -0
# exceed all_1 | sup_2 | Dec            0       -164.5         -inf           -0
# exceed all_1 | sup_3 | Int            0            0         -inf           -0
# exceed all_1 | sup_3 | Jan            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Feb            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Mar            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Apr            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | May            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Jun            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Jul            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Aug            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Sep            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Oct            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Nov            0     -205.938         -inf           -0
# exceed all_1 | sup_3 | Dec            0     -205.938         -inf           -0
# exceed all_1 | sup_4 | Int            0            0         -inf           -0
# exceed all_1 | sup_4 | Jan            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Feb            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Mar            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Apr            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | May            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Jun            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Jul            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Aug            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Sep            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Oct            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Nov            0     -192.092         -inf           -0
# exceed all_1 | sup_4 | Dec            0     -192.092         -inf           -0
# exceed all_1 | sup_5 | Int            0            0         -inf           -0
# exceed all_1 | sup_5 | Jan            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Feb            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Mar            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Apr            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | May            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Jun            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Jul            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Aug            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Sep            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Oct            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Nov            0     -136.875         -inf           -0
# exceed all_1 | sup_5 | Dec            0     -136.875         -inf           -0
# exceed all_2 | sup_1 | Int            0            0         -inf           -0
# exceed all_2 | sup_1 | Jan            0           -9         -inf           -0
# exceed all_2 | sup_1 | Feb            0           -9         -inf           -0
# exceed all_2 | sup_1 | Mar            0           -9         -inf           -0
# exceed all_2 | sup_1 | Apr            0           -9         -inf           -0
# exceed all_2 | sup_1 | May            0           -9         -inf           -0
# exceed all_2 | sup_1 | Jun            0           -9         -inf           -0
# exceed all_2 | sup_1 | Jul            0           -9         -inf           -0
# exceed all_2 | sup_1 | Aug            0           -9         -inf           -0
# exceed all_2 | sup_1 | Sep            0           -9         -inf           -0
# exceed all_2 | sup_1 | Oct            0           -9         -inf           -0
# exceed all_2 | sup_1 | Nov            0           -9         -inf           -0
# exceed all_2 | sup_1 | Dec            0           -9         -inf           -0
# exceed all_2 | sup_2 | Int            0            0         -inf           -0
# exceed all_2 | sup_2 | Jan            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Feb            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Mar            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Apr            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | May            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Jun            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Jul            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Aug            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Sep            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Oct            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Nov            0         -6.4         -inf           -0
# exceed all_2 | sup_2 | Dec            0         -6.4         -inf           -0
# exceed all_2 | sup_3 | Int            0            0         -inf           -0
# exceed all_2 | sup_3 | Jan            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Feb            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Mar            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Apr            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | May            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Jun            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Jul            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Aug            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Sep            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Oct            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Nov            0      -8.3125         -inf           -0
# exceed all_2 | sup_3 | Dec            0      -8.3125         -inf           -0
# exceed all_2 | sup_4 | Int            0            0         -inf           -0
# exceed all_2 | sup_4 | Jan            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Feb            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Mar            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Apr            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | May            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Jun            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Jul            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Aug            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Sep            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Oct            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Nov            0     -7.58333         -inf           -0
# exceed all_2 | sup_4 | Dec            0     -7.58333         -inf           -0
# exceed all_2 | sup_5 | Int            0            0         -inf           -0
# exceed all_2 | sup_5 | Jan            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Feb            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Mar            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Apr            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | May            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Jun            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Jul            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Aug            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Sep            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Oct            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Nov            0     -5.20833         -inf           -0
# exceed all_2 | sup_5 | Dec            0     -5.20833         -inf           -0
# exceed all_3 | sup_1 | Int            0            0         -inf           -0
# exceed all_3 | sup_1 | Jan            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Feb            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Mar            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Apr            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | May            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Jun            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Jul            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Aug            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Sep            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Oct            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Nov            0     -1.86667         -inf           -0
# exceed all_3 | sup_1 | Dec            0     -1.86667         -inf           -0
# exceed all_3 | sup_2 | Int            0            0         -inf           -0
# exceed all_3 | sup_2 | Jan            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Feb            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Mar            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Apr            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | May            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Jun            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Jul            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Aug            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Sep            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Oct            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Nov            0         -1.1         -inf           -0
# exceed all_3 | sup_2 | Dec            0         -1.1         -inf           -0
# exceed all_3 | sup_3 | Int            0            0         -inf           -0
# exceed all_3 | sup_3 | Jan            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Feb            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Mar            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Apr            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | May            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Jun            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Jul            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Aug            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Sep            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Oct            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Nov            0       -1.625         -inf           -0
# exceed all_3 | sup_3 | Dec            0       -1.625         -inf           -0
# exceed all_3 | sup_4 | Int            0            0         -inf           -0
# exceed all_3 | sup_4 | Jan            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Feb            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Mar            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Apr            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | May            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Jun            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Jul            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Aug            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Sep            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Oct            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Nov            0         -1.4         -inf           -0
# exceed all_3 | sup_4 | Dec            0         -1.4         -inf           -0
# exceed all_3 | sup_5 | Int            0            0         -inf           -0
# exceed all_3 | sup_5 | Jan            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Feb            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Mar            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Apr            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | May            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Jun            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Jul            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Aug            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Sep            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Oct            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Nov            0    -0.833333         -inf           -0
# exceed all_3 | sup_5 | Dec            0    -0.833333         -inf           -0
# exceed all_4 | sup_1 | Int            0            0         -inf           -0
# exceed all_4 | sup_1 | Jan            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Feb            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Mar            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Apr            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | May            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Jun            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Jul            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Aug            0     -686.667         -inf           -0
# exceed all_4 | sup_1 | Sep            0     -686.667         -inf           -0
# ...
#    lower_209            <            0      1.86667        -1500         -inf     -886.111
#   lower_2010            <            0      1.86667        -1500         -inf     -886.111
#   lower_2011            <            0      1.86667        -1500         -inf     -886.111
#   lower_2012            <            0      1.86667        -1500         -inf     -886.111
#    lower_211            <            0          1.1        -1200         -inf            0
#    lower_212            <            0          1.1        -1200         -inf            0
#    lower_213            <            0          1.1        -1200         -inf            0
#    lower_214            <            0          1.1        -1200         -inf            0
#    lower_215            <            0          1.1        -1200         -inf            0
#    lower_216            <            0          1.1        -1200         -inf            0
#    lower_217            <            0          1.1        -1200         -inf            0
#    lower_218            <            0          1.1        -1200         -inf            0
#    lower_219            <            0          1.1        -1200         -inf            0
#   lower_2110            <            0          1.1        -1200         -inf            0
#   lower_2111            <            0          1.1        -1200         -inf            0
#   lower_2112            <            0          1.1        -1200         -inf            0
#    lower_221            <            0        1.625        -2500         -inf            0
#    lower_222            <            0        1.625        -2500         -inf            0
#    lower_223            <            0        1.625        -2500         -inf            0
#    lower_224            <            0        1.625        -2500         -inf            0
#    lower_225            <            0        1.625        -2500         -inf            0
#    lower_226            <            0        1.625        -2500         -inf            0
#    lower_227            <            0        1.625        -2500         -inf            0
#    lower_228            <            0        1.625        -2500         -inf            0
#    lower_229            <            0        1.625        -2500         -inf            0
#   lower_2210            <            0        1.625        -2500         -inf            0
#   lower_2211            <            0        1.625        -2500         -inf            0
#   lower_2212            <            0        1.625        -2500         -inf            0
#    lower_231            <            0          1.4        -2000         -inf            0
#    lower_232            <            0          1.4        -2000         -inf            0
#    lower_233            <            0          1.4        -2000         -inf            0
#    lower_234            <            0          1.4        -2000         -inf            0
#    lower_235            <            0          1.4        -2000         -inf            0
#    lower_236            <            0          1.4        -2000         -inf            0
#    lower_237            <            0          1.4        -2000         -inf            0
#    lower_238            <            0          1.4        -2000         -inf            0
#    lower_239            <            0          1.4        -2000         -inf            0
#   lower_2310            <            0          1.4        -2000         -inf            0
#   lower_2311            <            0          1.4        -2000         -inf            0
#   lower_2312            <            0          1.4        -2000         -inf            0
#    lower_241            <            0     0.833333         -800         -inf            0
#    lower_242            <            0     0.833333         -800         -inf            0
#    lower_243            <            0     0.833333         -800         -inf            0
#    lower_244            <            0     0.833333         -800         -inf            0
#    lower_245            <            0     0.833333         -800         -inf            0
#    lower_246            <            0     0.833333         -800         -inf            0
#    lower_247            <            0     0.833333         -800         -inf            0
#    lower_248            <            0     0.833333         -800         -inf            0
#    lower_249            <            0     0.833333         -800         -inf            0
#   lower_2410            <            0     0.833333         -800         -inf            0
#   lower_2411            <            0     0.833333         -800         -inf            0
#   lower_2412            <            0     0.833333         -800         -inf            0
#    lower_301            <            0      644.062          -42     -48.3889            0
#    lower_302            <            0      644.062          -42     -48.3889            0
#    lower_303            <            0      644.062          -42     -48.3889            0
#    lower_304            <            0      644.062          -42     -48.3889            0
#    lower_305            <            0      644.062          -42     -48.3889            0
#    lower_306            <            0      644.062          -42     -48.3889            0
#    lower_307            <            0      644.062          -42     -48.3889            0
#    lower_308            <            0      644.062          -42     -48.3889            0
#    lower_309            <            0      644.062          -42     -48.3889            0
#   lower_3010            <            0      644.062          -42     -48.3889            0
#   lower_3011            <            0      644.062          -42     -48.3889            0
#   lower_3012            <            0      644.062          -42     -48.3889            0
#    lower_311            <            0          513         -100         -inf            0
#    lower_312            <            0          513         -100         -inf            0
#    lower_313            <            0          513         -100         -inf            0
#    lower_314            <            0          513         -100         -inf            0
#    lower_315            <            0          513         -100         -inf            0
#    lower_316            <            0          513         -100         -inf            0
#    lower_317            <            0          513         -100         -inf            0
#    lower_318            <            0          513         -100         -inf            0
#    lower_319            <            0          513         -100         -inf            0
#   lower_3110            <            0          513         -100         -inf            0
#   lower_3111            <            0          513         -100         -inf            0
#   lower_3112            <            0          513         -100         -inf            0
#    lower_321            <            0      642.812          -85         -inf     -6.38889
#    lower_322            <            0      642.812          -85         -inf     -6.38889
#    lower_323            <            0      642.812          -85         -inf     -6.38889
#    lower_324            <            0      642.812          -85         -inf     -6.38889
#    lower_325            <            0      642.812          -85         -inf     -6.38889
#    lower_326            <            0      642.812          -85         -inf     -6.38889
#    lower_327            <            0      642.812          -85         -inf     -6.38889
#    lower_328            <            0      642.812          -85         -inf     -6.38889
#    lower_329            <            0      642.812          -85         -inf     -6.38889
#   lower_3210            <            0      642.812          -85         -inf     -6.38889
#   lower_3211            <            0      642.812          -85         -inf     -6.38889
#   lower_3212            <            0      642.812          -85         -inf     -6.38889
#    lower_331            <            0      599.083         -100         -inf            0
#    lower_332            <            0      599.083         -100         -inf            0
#    lower_333            <            0      599.083         -100         -inf            0
#    lower_334            <            0      599.083         -100         -inf            0
#    lower_335            <            0      599.083         -100         -inf            0
#    lower_336            <            0      599.083         -100         -inf            0
#    lower_337            <            0      599.083         -100         -inf            0
#    lower_338            <            0      599.083         -100         -inf            0
#    lower_339            <            0      599.083         -100         -inf            0
#   lower_3310            <            0      599.083         -100         -inf            0
#   lower_3311            <            0      599.083         -100         -inf            0
#   lower_3312            <            0      599.083         -100         -inf            0
#    lower_341            <            0      426.667          -75         -inf            0
#    lower_342            <            0      426.667          -75         -inf            0
#    lower_343            <            0      426.667          -75         -inf            0
#    lower_344            <            0      426.667          -75         -inf            0
#    lower_345            <            0      426.667          -75         -inf            0
#    lower_346            <            0      426.667          -75         -inf            0
#    lower_347            <            0      426.667          -75         -inf            0
#    lower_348            <            0      426.667          -75         -inf            0
#    lower_349            <            0      426.667          -75         -inf            0
#   lower_3410            <            0      426.667          -75         -inf            0
#   lower_3411            <            0      426.667          -75         -inf            0
#   lower_3412            <            0      426.667          -75         -inf            0
#    lower_401            <            0      168.667          -84         -inf     -47.0833
#    lower_402            <            0      168.667          -84         -inf     -47.0833
#    lower_403            <            0      168.667          -84         -inf     -47.0833
#    lower_404            <            0      168.667          -84         -inf     -47.0833
#    lower_405            <            0      168.667          -84         -inf     -47.0833
#    lower_406            <            0      168.667          -84         -inf     -47.0833
#    lower_407            <            0      168.667          -84         -inf     -47.0833
#    lower_408            <            0      168.667          -84         -inf     -47.0833
#    lower_409            <            0      168.667          -84         -inf     -47.0833
#   lower_4010            <            0      168.667          -84         -inf     -47.0833
#   lower_4011            <            0      168.667          -84         -inf     -47.0833
#   lower_4012            <            0      168.667          -84         -inf     -47.0833
#    lower_411            <            0        122.5         -100         -inf            0
#    lower_412            <            0        122.5         -100         -inf            0
#    lower_413            <            0        122.5         -100         -inf            0
#    lower_414            <            0        122.5         -100         -inf            0
#    lower_415            <            0        122.5         -100         -inf            0
#    lower_416            <            0        122.5         -100         -inf            0
#    lower_417            <            0        122.5         -100         -inf            0
#    lower_418            <            0        122.5         -100         -inf            0
#    lower_419            <            0        122.5         -100         -inf            0
#   lower_4110            <            0        122.5         -100         -inf            0
#   lower_4111            <            0        122.5         -100         -inf            0
#   lower_4112            <            0        122.5         -100         -inf            0
#    lower_421            <            0       156.25         -100         -inf            0
#    lower_422            <            0       156.25         -100         -inf            0
#    lower_423            <            0       156.25         -100         -inf            0
#    lower_424            <            0       156.25         -100         -inf            0
#    lower_425            <            0       156.25         -100         -inf            0
#    lower_426            <            0       156.25         -100         -inf            0
#    lower_427            <            0       156.25         -100         -inf            0
#    lower_428            <            0       156.25         -100         -inf            0
#    lower_429            <            0       156.25         -100         -inf            0
#   lower_4210            <            0       156.25         -100         -inf            0
#   lower_4211            <            0       156.25         -100         -inf            0
#   lower_4212            <            0       156.25         -100         -inf            0
#    lower_431            <            0      144.083         -120         -inf            0
#    lower_432            <            0      144.083         -120         -inf            0
#    lower_433            <            0      144.083         -120         -inf            0
#    lower_434            <            0      144.083         -120         -inf            0
#    lower_435            <            0      144.083         -120         -inf            0
#    lower_436            <            0      144.083         -120         -inf            0
#    lower_437            <            0      144.083         -120         -inf            0
#    lower_438            <            0      144.083         -120         -inf            0
#    lower_439            <            0      144.083         -120         -inf            0
#   lower_4310            <            0      144.083         -120         -inf            0
#   lower_4311            <            0      144.083         -120         -inf            0
#   lower_4312            <            0      144.083         -120         -inf            0
#    lower_441            <            0       101.25          -50         -inf            0
#    lower_442            <            0       101.25          -50         -inf            0
#    lower_443            <            0       101.25          -50         -inf            0
#    lower_444            <            0       101.25          -50         -inf            0
#    lower_445            <            0       101.25          -50         -inf            0
#    lower_446            <            0       101.25          -50         -inf            0
#    lower_447            <            0       101.25          -50         -inf            0
#    lower_448            <            0       101.25          -50         -inf            0
#    lower_449            <            0       101.25          -50         -inf            0
#   lower_4410            <            0       101.25          -50         -inf            0
#   lower_4411            <            0       101.25          -50         -inf            0
#   lower_4412            <            0       101.25          -50         -inf            0
#         R869            =            0            0            0 -9.41947e+06          inf
